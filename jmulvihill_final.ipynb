# %% [markdown]
# # Citation Cheat Codes: Do Certain Institutions or Topics Influence Citation Counts for Academic Research?

# %% [markdown]
# ## Research Question
# **Given** the OpenAlex tables “Works” and “Works Authorships” provide information about
# citation counts, authors, and the institution that published these works between 2020 and 2025.
#
# **Then** we aim to identify which institutions and combinations of institutions are most frequently
# associated with highly cited research during this period.
#
# **How** we will approach this is by each highly cited paper we will look at the institutions
# represented by its authors and analyze which institutions frequently appear together in impactful
# research. Using frequent pattern mining we will identify recurring patterns and determine which
# combinations are most associated with highly cited works.

# %% [markdown]
# ## Institutions Publishing Highly Cited Works and their Co-Authorship Patterns

# %% [markdown]
# ## Imported Libraries

# %%
import pandas as pd
import pyarrow.parquet as pq
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import pyarrow.parquet as pypq
import textwrap 

# For sampling
import random

# For Apriori (Frequent Pattern Mining)
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# For counting and filtering frequent item pairs
from collections import Counter

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 80)

# ---------------------------------------------------------
# 📂 GLOBAL PATHS - DO NOT CHANGE THESE
# ---------------------------------------------------------
BASE_PATH = Path("/data/shared/OpenAlex/processed-snapshots")
PARQUET_PATH = BASE_PATH / "parquet-files" / "may-2025"
CSV_PATH = BASE_PATH / "csv-files" / "may-2025"

print(f"✅ Data Directories Set:\n  - Parquet: {PARQUET_PATH}\n  - CSV: {CSV_PATH}")

# Focusing on works published within the most recent complete five year range, 2019-2024
MIN_YEAR = 2019
MAX_YEAR = 2024 # 2025 does not have complete data on all works published that year

# Consider a work with 50 or more citations "highly cited"
MIN_CITS = 50
# Out:
# ✅ Data Directories Set:
#   - Parquet: /data/shared/OpenAlex/processed-snapshots/parquet-files/may-2025
#   - CSV: /data/shared/OpenAlex/processed-snapshots/csv-files/may-2025

# %% [markdown]
# ## Peek Parquet (Inspects File Schemas)

# %%
def peek_parquet(path):
    """
    peeks at a parquet file (or a directory containing parquet files) without reading the whole thing and prints the following:
    * Path
    * schema
    * number of pieces (fragments)
    * number of rows 
    """
    path = Path(path)
    parq_file = pypq.ParquetDataset(path)
    piece_count = len(parq_file.fragments)
    schema = textwrap.indent(parq_file.schema.to_string(), ' '*4)
    row_count = sum(frag.count_rows() for frag in parq_file.fragments)
    
    st = [
        f'Name: {path.stem!r}',  
        f'Path: {str(path)!r}',
        f'Files: {piece_count:,}',
        f'Rows: {row_count:,}',
        f'Schema:\n{schema}',
        f'5 random rows:',
    ]
    print('\n'.join(st))
    sample_df = parq_file.fragments[0].head(5).to_pandas()  # read 5 rows from the first fragment
    display(sample_df)

    return

# %% [markdown]
# ## Primary Tables: Works and Works Authorships

# %%
peek_parquet(PARQUET_PATH / 'works')
# Out:
# Name: 'works'
# Path: '/data/shared/OpenAlex/processed-snapshots/parquet-files/may-2025/works'
# Files: 879
# Rows: 267,515,390
# Schema:
#     work_id: int64
#     doi: string
#     title: string
#     publication_year: int16
#     publication_date: timestamp[ms]
#     type: dictionary<values=string, indices=int32, ordered=0>
#     type_crossref: dictionary<values=string, indices=int32, ordered=0>
#     cited_by_count: uint32
#     num_authors: uint16
#     num_locations: uint16
#     num_references: uint16
#     language: dictionary<values=string, indices=int32, ordered=0>
#     has_complete_institution_info: bool
#     has_grant_info: bool
#     has_keywords: bool
#     is_retracted: bool
#     is_paratext: bool
#     created_date: timestamp[ms]
#     gz_path: dictionary<values=string, indices=int32, ordered=0>
#     -- schema metadata --
#     pandas: '{"index_columns": [], "column_indexes": [{"name": null, "field_n' + 2664
# 5 random rows:
#       work_id                      doi  \
# 0  4298954679                     <NA>
# 1  4367174134  10.41014/jmb.2301.01011
#
#                                                                              title  \
# 0                       Anomalous cooling of the parallel velocity in seeded beams
# 1  Comparative Genomic Analysis and BTEX Degradation Pathways of a Thermotolera...
#
#    publication_year publication_date     type    type_crossref  \
# 0              2004       2004-06-16  article   posted-content
# 1              2023       2023-04-10  article  journal-article
#
#    cited_by_count  num_authors  num_locations  num_references language  \
# 0               0            4              6               0       en
# 1               0            6              1               0       en
#
#    has_complete_institution_info  has_grant_info  has_keywords  is_retracted  \
# 0                          False           False         False         False
# 1                           True           False         False         False
#
#    is_paratext created_date              gz_path
# 0        False   2022-10-02  2023-05-29_part_000
# 1        False   2023-04-28  2023-05-29_part_000

# %%
# Construct a dataframe from the original parquet files
works_df = (
  pd.read_parquet(
    PARQUET_PATH / 'works',

    # Include relevant columns to this analysis
    columns=['work_id', 'cited_by_count', 'has_complete_institution_info'],

    # Only include papers published within our desired period of analysis
    # Only include papers that have received 50 or more citations
    # Make sure it has complete information about publication
    filters=[
      [
        ('publication_year', '>=', MIN_YEAR), ('publication_year', '<=', MAX_YEAR),
        ('cited_by_count', '>=', MIN_CITS), ('has_complete_institution_info', '==', True), 
      ]
    ],
  )
)

# %% [markdown]
# Create a DataFrame of works with their work ID and citation count including only "highly cited" (50 or more citations) works. We are only interested in "highly cited" works published within 2019-2024 and have complete information regarding their institution of origin.

# %%
display(works_df.head())
# Out:
#       work_id  cited_by_count  has_complete_institution_info
# 0  4223541591             184                           True
# 1  3025854696              67                           True
# 2  2936380844              84                           True
# 3  2047643587              86                           True
# 4  4225729190             115                           True

# %%
peek_parquet(PARQUET_PATH / 'works_authorships')
# Out:
# Name: 'works_authorships'
# Path: '/data/shared/OpenAlex/processed-snapshots/parquet-files/may-2025/works_authorships'
# Files: 876
# Rows: 955,891,469
# Schema:
#     work_id: int64
#     author_position: dictionary<values=string, indices=int32, ordered=0>
#     author_id: int64
#     author_name: string
#     raw_author_name: string
#     institution_lineage_level: int8
#     assigned_institution: bool
#     institution_id: int64
#     institution_name: dictionary<values=string, indices=int32, ordered=0>
#     country_code: dictionary<values=string, indices=int32, ordered=0>
#     raw_affiliation_string: string
#     publication_year: int16
#     is_corresponding: bool
#     -- schema metadata --
#     pandas: '{"index_columns": [], "column_indexes": [{"name": null, "field_n' + 1971
# 5 random rows:
#       work_id author_position   author_id             author_name  \
# 0  4298954679           first  5058811708            Alain Miffre
# 1  4298954679          middle  5030850284          Marion Jacquey
# 2  4298954679          middle  5080689989           Gérard Trénec
# 3  4298954679            last  5025008933                J. Vigué
# 4  4367174134           first  5051167699  Chandran Sathesh-Prabu
#
#   raw_author_name  institution_lineage_level  assigned_institution  \
# 0            <NA>                          0                  True
# 1            <NA>                          0                  True
# 2            <NA>                          0                  True
# 3            <NA>                          0                  True
# 4            <NA>                          0                 False
#
#    institution_id institution_name country_code  \
# 0            <NA>              NaN          NaN
# 1            <NA>              NaN          NaN
# 2            <NA>              NaN          NaN
# 3            <NA>              NaN          NaN
# 4            <NA>              NaN          NaN
#
#                                                             raw_affiliation_string  \
# 0                                                                             <NA>
# 1                                                                             <NA>
# 2                                                                             <NA>
# 3                                                                             <NA>
# 4  School of Energy and Chemical Engineering, Ulsan National Institute of Scien...
#
#    publication_year  is_corresponding
# 0              2004             False
# 1              2004             False
# 2              2004             False
# 3              2004             False
# 4              2023             False

# %%
# A set of the relevant work IDs (highly cited) filtered in the previous step
# Use a set to avoid storing duplicates
work_ids = set(works_df.work_id)

# Construct a dataframe from the original parquet files
works_authors_df = (
  pd.read_parquet(
    PARQUET_PATH / 'works_authorships',

    # Include relevant columns to this analysis
    columns=['work_id', 'institution_id', 
             'institution_name', 'publication_year'],
    
    # Only load authorship information for works that survived the initial filtering when creating works_df
    # Only include works published in 2019-2024
    filters=[[
      ('work_id', 'in', work_ids),
      ('publication_year', '>=', MIN_YEAR), ('publication_year', '<=', MAX_YEAR)
    ]],
  )
)

# %% [markdown]
# This DataFrame works_authors_df loads the authorship information for the works filtered out in creating the works_df DataFrame. Creating this DataFrame will fetch the institution information for the "highly cited" works mined along with their publication year.

# %%
display(works_authors_df)
# Out:
#             work_id  institution_id                 institution_name  \
# 0        4223541591        38706770  Guilin University of Technology
# 1        4223541591        38706770  Guilin University of Technology
# 2        4223541591        38706770  Guilin University of Technology
# 3        4223541591        38706770  Guilin University of Technology
# 4        3025854696       138690464              University of Ghana
# ...             ...             ...                              ...
# 9136968  4403686047       204983213   Harbin Institute of Technology
# 9136969  4403686047       204983213   Harbin Institute of Technology
# 9136970  4403686047       204983213   Harbin Institute of Technology
# 9136971  4403686047       204983213   Harbin Institute of Technology
# 9136972  4403686047       204983213   Harbin Institute of Technology
#
#          publication_year
# 0                    2022
# 1                    2022
# 2                    2022
# 3                    2022
# 4                    2020
# ...                   ...
# 9136968              2024
# 9136969              2024
# 9136970              2024
# 9136971              2024
# 9136972              2024
#
# [9136973 rows x 4 columns]

# %% [markdown]
# # Highly Cited Works and their Institution of Origin

# %%
# Create a temporary dataframe to merge the works and works_authors tables
temp_df = pd.merge(
    works_authors_df,
    works_df,

    # They both share work_id
    on='work_id',

    # Combines rows when there is a matching column
    how='inner'
)

# Drop duplicates from the newly merged dataframes, keep first occurrence
# Pay attention to work ID and institution ID combos for identifying duplicates
works_institutions_df = temp_df.drop_duplicates(keep='first', subset=['work_id', 'institution_id'])

# %% [markdown]
# Create a new DataFrame works_institutions_df which combines the desired information mined earlier into one DataFrame for easier analysis.

# %%
display(works_institutions_df.head())
# Out:
#        work_id  institution_id                   institution_name  \
# 0   4223541591        38706770    Guilin University of Technology
# 4   3025854696       138690464                University of Ghana
# 5   3025854696       130828816                University of Leeds
# 7   2936380844        63098007   Liverpool John Moores University
# 12  2936380844      4210129695  United Utilities (United Kingdom)
#
#     publication_year  cited_by_count  has_complete_institution_info
# 0               2022             184                           True
# 4               2020              67                           True
# 5               2020              67                           True
# 7               2019              84                           True
# 12              2019              84                           True

# %%
# Save as a parquet file to quickly load filtered data in event of a kernel crash
works_institutions_df.to_parquet(path='/home/jupyter-jmulvihill@luc.edu-eebe5/works_institutions.parquet')

# %%
works_institutions_df = pd.read_parquet('/home/jupyter-jmulvihill@luc.edu-eebe5/works_institutions.parquet')

# %%
# Sanity check
display(works_institutions_df.head())
# Out:
#        work_id  institution_id                   institution_name  \
# 0   4223541591        38706770    Guilin University of Technology
# 4   3025854696       138690464                University of Ghana
# 5   3025854696       130828816                University of Leeds
# 7   2936380844        63098007   Liverpool John Moores University
# 12  2936380844      4210129695  United Utilities (United Kingdom)
#
#     publication_year  cited_by_count  has_complete_institution_info
# 0               2022             184                           True
# 4               2020              67                           True
# 5               2020              67                           True
# 7               2019              84                           True
# 12              2019              84                           True

# %% [markdown]
# Count of Highly Cited Works Published in 2019-2024

# %%
# Find the total number of highly cited works published among all institutions per year
hc_works_per_year = (
    works_institutions_df

    # Group works counts by publication year
    .groupby('publication_year')
    .agg(
        
        # Number of unique work IDs per publication year is amount of highly cited works published that year
        works_that_year=('work_id', 'nunique'),
    )
)

# %%
display(hc_works_per_year)
# Out:
#                   works_that_year
# publication_year
# 2019                       270170
# 2020                       253657
# 2021                       163753
# 2022                        81478
# 2023                        31134
# 2024                         3714

# %%
# Plot the total number of highly cited works published that year
hc_works_by_year = hc_works_per_year.plot.bar(color='blue')

# Title and label the graph as approprite
hc_works_by_year.set_title(label='Highly Cited Works Published per Year in 2019-2024', fontsize=24, color='black')
hc_works_by_year.set_xlabel('Year', fontsize=18, color='black')
hc_works_by_year.set_ylabel('Total Publications', fontsize=18, color='black')
hc_works_by_year.legend(['Total Publications'])

# Annotate the bars, put them in decimal format
hc_works_by_year.bar_label(hc_works_by_year.containers[0], fmt='%d', label_type='edge', color='black')
# Out:
# [Text(0, 0, '270170'),
#  Text(0, 0, '253657'),
#  Text(0, 0, '163753'),
#  Text(0, 0, '81478'),
#  Text(0, 0, '31134'),
#  Text(0, 0, '3714')]

# %% [markdown]
# For each year 2019-2024, these are the amounts of highly cited works that were published that year. The data is positively (right) skewed as majority of the data comes from the years 2019-2021. These works have been out for longer than the ones in 2022-2024, so they had more time to accumulate more citations.

# %% [markdown]
# # Which Institutions are Publishing Highly Cited Works in 2019-2024?

# %%
# Find the total number of highly cited works published by institution between 2019-2024
total_publications = (
    works_institutions_df

    # Group publication counts by institution ID in the event of duplicate names
    .groupby('institution_id')
    .agg(

        # Look at the first occurrence of the institution name
        institution=('institution_name', 'first'),

        # Number of unique work IDs per institution is the amount they published
        total_publications=('work_id', 'nunique'),
    )
        
     # Sort by total publication count in descending order
    .sort_values(by='total_publications', ascending=False)
)

# %%
display(total_publications.head())
# Out:
#                                                  institution  \
# institution_id
# 19820366                         Chinese Academy of Sciences
# 1294671590      Centre National de la Recherche Scientifique
# 124357947                               University of London
# 136199984                                 Harvard University
# 4210165038         University of Chinese Academy of Sciences
#
#                 total_publications
# institution_id
# 19820366                     40696
# 1294671590                   17541
# 124357947                    17177
# 136199984                    16164
# 4210165038                   14125

# %%
# Plot the top ten institutions with most highly cited works published 
# Dataframe is sorted, first 10 rows will have the most highly cited works published
ten_most_published = total_publications.head(10).plot.barh(
    x='institution',
    y='total_publications',
    color='blue'
)

# Title and label the graph as approprite
ten_most_published.set_title(label='Top 10 Institutions with Most Highly Cited Works Published in 2019-2024', fontsize=24, color='black')
ten_most_published.set_xlabel('Total Publications', fontsize=18, color='black')
ten_most_published.set_ylabel('Institution Name', fontsize=18, color='black')
ten_most_published.legend(['Total Publications'])

# Invert the y-axis to sort the bars in descending order
ten_most_published.invert_yaxis()

# Annotate the bars, put them in decimal format
ten_most_published.bar_label(ten_most_published.containers[0], fmt='%d', label_type='center', color='white')
# Out:
# [Text(0, 0, '40696'),
#  Text(0, 0, '17541'),
#  Text(0, 0, '17177'),
#  Text(0, 0, '16164'),
#  Text(0, 0, '14125'),
#  Text(0, 0, '11530'),
#  Text(0, 0, '10652'),
#  Text(0, 0, '10369'),
#  Text(0, 0, '9503'),
#  Text(0, 0, '9318')]

# %% [markdown]
# These ten institutions have the most highly cited works published between the years 2019-2024. Many of these are world-renowned national or private institutions with massive research budgets. For example, Chinese Academy of Sciences and Centre National de la Recherche Scientifique are among the world's largest research institutions. Harvard and Stanford are among the most prestigious higher education institutions in the world.

# %% [markdown]
# # Which Institutions Receive the Most Citations for Highly Cited Works in 2019-2024?

# %%
# Find the total number of citations among all works published by an institution
total_citations = (
    works_institutions_df

    # Group citation counts by institution ID in the event of duplicate names
    .groupby('institution_id')
    .agg(

        # Look at the first occurrence of the institution name
        institution=('institution_name', 'first'),

        # Sum up total citation counts for each institution across all of their highly cited published works
        total_citations=('cited_by_count', 'sum'),
    )
        
     # Sort by total citation count in descending order
    .sort_values(by='total_citations', ascending=False)
)

# %%
display(total_citations.head())
# Out:
#                                                  institution  total_citations
# institution_id
# 19820366                         Chinese Academy of Sciences          4836906
# 124357947                               University of London          2423491
# 136199984                                 Harvard University          2358550
# 1294671590      Centre National de la Recherche Scientifique          2082424
# 4210165038         University of Chinese Academy of Sciences          1631559

# %%
# Plot the top ten institutions with most citations across works published
# Dataframe is sorted, first 10 rows will have the most citations
ten_most_cited = total_citations.head(10).plot.barh(
    x='institution',
    y='total_citations',
    color='blue'
)

# Title and label the graph as approprite
ten_most_cited.set_title(label='Top 10 Institutions with Most Citations among Highly Cited Works Published in 2019-2024', fontsize=24, color='black')
ten_most_cited.set_xlabel('Total Citations (in Millions)', fontsize=18, color='black')
ten_most_cited.set_ylabel('Institution Name', fontsize=18, color='black')
ten_most_cited.legend(['Total Citations'])

# Invert the y-axis to sort the bars in descending order
ten_most_cited.invert_yaxis()

# Annotate the bars, put them in decimal format
ten_most_cited.bar_label(ten_most_cited.containers[0], fmt='%d', label_type='center', color='white')
# Out:
# [Text(0, 0, '4836906'),
#  Text(0, 0, '2423491'),
#  Text(0, 0, '2358550'),
#  Text(0, 0, '2082424'),
#  Text(0, 0, '1631559'),
#  Text(0, 0, '1523720'),
#  Text(0, 0, '1453137'),
#  Text(0, 0, '1443292'),
#  Text(0, 0, '1320583'),
#  Text(0, 0, '1237485')]

# %% [markdown]
# These ten institutions received the most citations across all of their highly cited works published between 2019-2024. There is a lot of overlap with the table "Top 10 Institutions with Most Highly Cited Works Published in 2019-2024" suggesting that the sheer volume of works published by these institutions inflates their citation counts.

# %% [markdown]
# # Co-Authorship Patterns among Institutions Publishing Highly Cited Works

# %% [markdown]
# Given the institutions that publish most of the highly cited works, do they collaborate with each other often or do they tend to stay within their own bubble?

# %% [markdown]
# ## Mapping Institution IDs

# %%
# Map an institution ID to its name 
institution_map = (
    works_institutions_df
    .groupby('institution_id')['institution_name']
    .agg(lambda x: x.mode().iloc[0])
    .to_dict()
)

# Preview mapping entries
print(f"Institution map: {len(institution_map):,} entries")
print("\nSample entries:")
for iid, name in list(institution_map.items())[:5]:
    print(f"{iid} → {name}")
# Out:
# Institution map: 45,062 entries
#
# Sample entries:
# 9507 → Sangji University
# 19722 → Ateneo de Manila University
# 41870 → Military Institute of Engineering
# 43886 → Sapientia Hungarian University of Transylvania
# 46017 → Kahramanmaraş Sütçü İmam University

# %% [markdown]
# Institutions are primarily identified via their institution ID. To make it human readable, map an institution ID to its string name.

# %% [markdown]
# ## Building Transactions

# %%
# Group each work ID to a set of institution IDs
work_institutions = (
    works_institutions_df
    .groupby('work_id')['institution_id']
    .apply(set)
)

# Convert to a list of lists for mlxtend
transactions = [list(institutions) for institutions in work_institutions]

# Preview the first transaction
sample_work  = work_institutions.index[0]
sample_ids   = transactions[0]
sample_names = [institution_map.get(i, 'Unknown') for i in sample_ids]
print(f"\nSample transaction (Work ID: {sample_work})")
print(f"Associated institution ID(s) : {sample_ids}")
print(f"Name(s)                      : {sample_names}")
# Out:
# Sample transaction (Work ID: 665341)
# Associated institution ID(s) : [np.int64(99065089)]
# Name(s)                      : ['Tsinghua University']

# %% [markdown]
# A transaction is represented by a group of institution IDs associated with a work.

# %%
# Use a sample size of 50,000 papers to mine frequent itemsets
SAMPLE_SIZE = 50000

# Fix the seed so re-running this cell gives the same sample
random.seed(2026)
if len(transactions) > SAMPLE_SIZE:
    transactions = random.sample(transactions, SAMPLE_SIZE)

# %% [markdown]
# Since this project explores all topics, I need to use a sample to prevent kernel crashes due to the sheer volume of data within **works_institutions**. The largest viable sample size I could successfully use was 50,000.

# %% [markdown]
# ## Constructing TransactionEncoder (for Apriori)

# %%
# Converts the transaction matrix into a one-hot encoded dataframe
# Required input format for Apriori to run
te = TransactionEncoder()

# Use fit_transform to learn the full item univerise, then encode each transaction
te_array = te.fit_transform(transactions)

# Construct a dataframe from the encoded matrix where columns represent institution IDs
te_df = pd.DataFrame(te_array, columns=te.columns_)

# Display the dimensions of the te matrix
print(f"Encoded matrix shape: {te_df.shape}")
print(f"{te_df.shape[0]:,} rows  (works / transactions)")
print(f"{te_df.shape[1]:,} cols  (unique institutions / items)")

# Display the sparsity of the matrix
sparsity = (~te_df).sum().sum() / te_df.size
print(f"\nSparsity: {sparsity:.2%} of values are False")

te_df.head()
# Out:
# Encoded matrix shape: (50000, 18896)
# 50,000 rows  (works / transactions)
# 18,896 cols  (unique institutions / items)
#
# Sparsity: 99.98% of values are False
#    9507        41870       46017       47844       52325       80043       \
# 0       False       False       False       False       False       False
# 1       False       False       False       False       False       False
# 2       False       False       False       False       False       False
# 3       False       False       False       False       False       False
# 4       False       False       False       False       False       False
#
#    189991      215927      226432      241749      ...  4407990181  \
# 0       False       False       False       False  ...       False
# 1       False       False       False       False  ...       False
# 2       False       False       False       False  ...       False
# 3       False       False       False       False  ...       False
# 4       False       False       False       False  ...       False
#
#    4407990293  4407990318  4407990416  4407990431  4408541744  4408542113  \
# 0       False       False       False       False       False       False
# 1       False       False       False       False       False       False
# 2       False       False       False       False       False       False
# 3       False       False       False       False       False       False
# 4       False       False       False       False       False       False
#
#    4408895851  4410514724  4410514767
# 0       False       False       False
# 1       False       False       False
# 2       False       False       False
# 3       False       False       False
# 4       False       False       False
#
# [5 rows x 18896 columns]

# %%
# Detect names shared by more than one institution ID
name_counts = pd.Series(institution_map.values()).value_counts()
duplicate_iids = set(name_counts[name_counts > 1].index)

# Build display label to differentiate institutions that share the same name
# Will be plain if the name is unique, in the format "Name [id]" if shared
institution_display_map = {
    iid: (f"{name} [{iid}]" if name in duplicate_iids else name)
    for iid, name in institution_map.items()
}

# Label the transaction encoder dataframe using the display map
labeled_te_df = te_df.rename(columns=institution_display_map)

labeled_te_df.head()
# Out:
#    Sangji University  Military Institute of Engineering  \
# 0              False                              False
# 1              False                              False
# 2              False                              False
# 3              False                              False
# 4              False                              False
#
#    Kahramanmaraş Sütçü İmam University  Al Akhawayn University  \
# 0                                False                   False
# 1                                False                   False
# 2                                False                   False
# 3                                False                   False
# 4                                False                   False
#
#    Fundação Oswaldo Cruz  Institut Curie  \
# 0                  False           False
# 1                  False           False
# 2                  False           False
# 3                  False           False
# 4                  False           False
#
#    University of Veterinary Medicine Hannover, Foundation  \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
#
#    University of Madras  Universiti Malaysia Kelantan  \
# 0                 False                         False
# 1                 False                         False
# 2                 False                         False
# 3                 False                         False
# 4                 False                         False
#
#    University of Cambridge  ...  SAnté INgenierie BIOlogie Saint-Etienne  \
# 0                    False  ...                                    False
# 1                    False  ...                                    False
# 2                    False  ...                                    False
# 3                    False  ...                                    False
# 4                    False  ...                                    False
#
#    Université Marie et Louis Pasteur  Indiana University Columbus  \
# 0                              False                        False
# 1                              False                        False
# 2                              False                        False
# 3                              False                        False
# 4                              False                        False
#
#    U.S. Army Materiel Command  Université Bourgogne Europe  \
# 0                       False                        False
# 1                       False                        False
# 2                       False                        False
# 3                       False                        False
# 4                       False                        False
#
#    United States Space Command  Region Jämtland Härjedalen  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
#
#    Sistema Nazionale per la Protezione dell'Ambiente  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Government of the Republic of China  Stichting Aeres Groep
# 0                                False                  False
# 1                                False                  False
# 2                                False                  False
# 3                                False                  False
# 4                                False                  False
#
# [5 rows x 18896 columns]

# %% [markdown]
# ## Apriori Search

# %%
# Testing five different min support thresholds: 
# institutions appearing in 0.2375% (the lowest I could run without crashing), 
# 0.3%, 0.35%, 0.4%, and 0.45% of papers respectively
min_supports = [0.002375, 0.003, 0.0035, 0.004, 0.0045]
counts = []
for ms in min_supports:
    fi = apriori(labeled_te_df, min_support=ms, use_colnames=True, verbose=0)

    # Append the length of each set of frequent itemsets to the list counts
    counts.append(len(fi))

# %%
# Convert the array data obtained from the Apriori search to dataframes for plotting
min_supports_df = pd.DataFrame(min_supports, columns=["MIN_SUPPORT"])
counts_df = pd.DataFrame(counts, columns=["Frequent Itemsets"])

# Construct a temporary dataframe combining the information for the minimum support
# and frequent itemsets counts to plot
min_supports_to_itemsets = pd.concat([min_supports_df, counts_df], axis=1)

# Construct two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Set a single title for both plots
fig.suptitle('Frequent Itemsets Found per MIN_SUPPORT Threshold', fontsize=24, color='black')

# Plot the combined dataframe on the left panel
ax1 = min_supports_to_itemsets.plot(x='MIN_SUPPORT', y='Frequent Itemsets', ax=ax1, color='blue', marker='o')

# Label the axes as appropriate
ax1.set_xlabel('MIN_SUPPORT Threshold', fontsize=16, color='black')
ax1.set_ylabel('Frequent Itemsets Count', fontsize=16, color='black')

# Add a vertical line annotation on the left panel for my chosen MIN_SUPPORT threshold
ax1.axvline(x=0.002375, color='magenta')

# Add a legend to the left panel to annotate the graph line and chosen MIN_SUPPORT threshold
ax1.legend(['Frequent Itemsets', 'My Chosen MIN_SUPPORT'])

# Plot the combined dataframe on the right panel
ax2 = min_supports_to_itemsets.plot(x='MIN_SUPPORT', y='Frequent Itemsets', ax=ax2, color='blue', marker='o')

# Label the axes as appropriate
ax2.set_xlabel('MIN_SUPPORT Threshold', fontsize=16, color='black')
ax2.set_ylabel('Frequent Itemsets Count', fontsize=16, color='black')

# Convert the right panel to a logarithmic axis
ax2.set_yscale('log')

# Add a vertical line annotation on the right panel for my chosen MIN_SUPPORT threshold
ax2.axvline(x=0.002375, color='magenta')

# Add a legend to the right panel to annotate the graph line and chosen MIN_SUPPORT threshold
ax2.legend(['Frequent Itemsets', 'My Chosen MIN_SUPPORT'])

# %% [markdown]
# Visualizes the total number of frequent itemsets plotted at each tested MIN_SUPPORT threshold. The vertical magenta line represents the MIN_SUPPORT threshold I chose for this analysis. My chosen MIN_SUPPORT threshold states that the authoring institution(s) appear in at least 0.2375% of all papers within the dataset. This chosen MIN_SUPPORT threshold yields 342 frequent itemsets, which is slightly above the middle of the recommended 100-500 frequent itemsets.

# %%
# Institution pair appears in at least 0.2375% of papers
MIN_SUPPORT = 0.002375

# Run the Apriori search at MIN_SUPPORT threshold 0.002375
print(f"Running Apriori at min_support threshold {MIN_SUPPORT}")
frequent_itemsets = apriori(
    labeled_te_df,
    min_support=MIN_SUPPORT,
    use_colnames=True,
    max_len=None,
    verbose=1,
)

# Sort found frequent itemsets by support
frequent_itemsets = frequent_itemsets.sort_values(by='support', ascending=False)

print(f"There are {len(frequent_itemsets):,} frequent itemsets at MIN_SUPPORT threshold {MIN_SUPPORT}")

display(frequent_itemsets.head())
# Out:
# Running Apriori at min_support threshold 0.002375
# Processing 5 combinations | Sampling itemset size 5 432
# There are 342 frequent itemsets at MIN_SUPPORT threshold 0.002375
#      support  \
# 17   0.04932
# 209  0.02236
# 109  0.02044
# 121  0.01948
# 263  0.01728
#
#                                                                             itemsets
# 17                                          frozenset({Chinese Academy of Sciences})
# 209                        frozenset({Centre National de la Recherche Scientifique})
# 109                                                frozenset({University of London})
# 121                                                  frozenset({Harvard University})
# 263  frozenset({Chinese Academy of Sciences, University of Chinese Academy of Sci...

# %%
# Add itemset length column for easy filtering
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(len)

# Display the proportion of frequent itemsets found for each size
print("Frequent itemsets found by size:")
print(frequent_itemsets['length'].value_counts().sort_index().to_string())
# Out:
# Frequent itemsets found by size:
# length
# 1    259
# 2     59
# 3     18
# 4      5
# 5      1

# %% [markdown]
# # Frequent Solo (1-Itemset) Institutions Publishing Highly Cited Works in 2019-2024 by Support

# %%
print("Frequent solo institutions publishing highly cited works between 2019-2024 by support:")
freq_insts = (
    
    # Filter to find the most frequent 1-itemsets
    frequent_itemsets[frequent_itemsets['length'] == 1]
    [['support', 'itemsets']]
)

display(freq_insts.head())
# Out:
# Frequent solo institutions publishing highly cited works between 2019-2024 by support:
#      support                                                   itemsets
# 17   0.04932                   frozenset({Chinese Academy of Sciences})
# 209  0.02236  frozenset({Centre National de la Recherche Scientifique})
# 109  0.02044                          frozenset({University of London})
# 121  0.01948                            frozenset({Harvard University})
# 253  0.01728     frozenset({University of Chinese Academy of Sciences})

# %%
# Sort by support in descending order
freq_insts = freq_insts.sort_values(by='support', ascending=False)

# Plot the top ten frequent solo institutions by support
# Dataframe is sorted, first 10 rows will have the highest support
top_ten_freq_insts = freq_insts.head(10).plot.barh(
    x='itemsets',
    y='support',
    color='blue'
)

# Title and label the graph as approprite
top_ten_freq_insts.set_title(label='Top 10 Frequent Solo Institutions by Support Publishing Highly Cited Works in 2019-2024', fontsize=24, color='black')
top_ten_freq_insts.set_xlabel('Support', fontsize=18, color='black')
top_ten_freq_insts.set_ylabel('Institution Name', fontsize=18, color='black')
top_ten_freq_insts.legend(['Support'])

# Invert the y-axis to sort the bars in descending order
top_ten_freq_insts.invert_yaxis()

# Annotate the bars, put in float format
top_ten_freq_insts.bar_label(top_ten_freq_insts.containers[0], fmt='%f', label_type='center', color='white')
# Out:
# [Text(0, 0, '0.049320'),
#  Text(0, 0, '0.022360'),
#  Text(0, 0, '0.020440'),
#  Text(0, 0, '0.019480'),
#  Text(0, 0, '0.017280'),
#  Text(0, 0, '0.013900'),
#  Text(0, 0, '0.012980'),
#  Text(0, 0, '0.012780'),
#  Text(0, 0, '0.012200'),
#  Text(0, 0, '0.011760')]

# %% [markdown]
# These are the top ten institutions solo publishing highly cited works between 2019-2024 with the highest support. There is a lot of overlap with the table "Top 10 Institutions with Most Highly Cited Works Published in 2019-2024" which makes sense as this measures the proportion of highly cited works found by institution in the sample. Order seems to have flipped around a little bit, likely due to how the sample was taken.

# %% [markdown]
# # Frequent Pairs (2-Itemset) of Institutions Publishing Highly Cited Works in 2019-2024 by Support

# %%
print("Frequent pairs of institutions publishing highly cited works between 2019-2024 by support:")
freq_inst_pairs = (
    
    # Filter to find the most frequent 2-itemsets
    frequent_itemsets[frequent_itemsets['length'] == 2]
    [['support', 'itemsets']]
)

display(freq_inst_pairs.head())
# Out:
# Frequent pairs of institutions publishing highly cited works between 2019-2024 by support:
#      support  \
# 263  0.01728
# 268  0.01008
# 266  0.00994
# 269  0.00816
# 301  0.00806
#
#                                                                             itemsets
# 263  frozenset({Chinese Academy of Sciences, University of Chinese Academy of Sci...
# 268                     frozenset({University College London, University of London})
# 266               frozenset({Office of Science, United States Department of Energy})
# 269                            frozenset({Harvard University, Mass General Brigham})
# 301  frozenset({United States Department of Health and Human Services, National I...

# %%
# Sort by support in descending order
freq_inst_pairs = freq_inst_pairs.sort_values(by='support', ascending=False)

# Plot the top ten pairs of institutions by support
# Dataframe is sorted, first 10 rows will have the highest support
top_ten_pairs = freq_inst_pairs.head(10).plot.barh(
    x='itemsets',
    y='support',
    color='blue'
)

# Title and label the graph as approprite
top_ten_pairs.set_title(label='Top 10 Frequent Institution Pairs Publishing Highly Cited Works in 2019-2024', fontsize=24, color='black')
top_ten_pairs.set_xlabel('Support', fontsize=18, color='black')
top_ten_pairs.set_ylabel('Institution Name', fontsize=18, color='black')
top_ten_pairs.legend(['Support'])

# Invert the y-axis to sort the bars in descending order
top_ten_pairs.invert_yaxis()

# Annotate the bars
top_ten_pairs.bar_label(top_ten_pairs.containers[0], fmt='%f', label_type='center', color='white')
# Out:
# [Text(0, 0, '0.017280'),
#  Text(0, 0, '0.010080'),
#  Text(0, 0, '0.009940'),
#  Text(0, 0, '0.008160'),
#  Text(0, 0, '0.008060'),
#  Text(0, 0, '0.007980'),
#  Text(0, 0, '0.006140'),
#  Text(0, 0, '0.006020'),
#  Text(0, 0, '0.005980'),
#  Text(0, 0, '0.005560')]

# %% [markdown]
# These are the top ten institutions publishing highly cited works in pairs between the years 2019-2024. There is less overlap with the top ten solo institutions publishing highly cited works which suggests that some of these institutions prefer to act independently. Additionally, among the institutions that publish together, there seems to be a preference to stay local as there does not seem to be a lot of international collaboration. A lot of these institutions are publishing with local federal institutions or their partners and subsidiaries. For example, Mass General Brigham is a teaching affiliate of Harvard University's medical school. There also seems to be a lot of federal institutions publishing together.

# %% [markdown]
# # Frequent Groups (n-Itemset) of Institutions Publishing Highly Cited Works in 2019-2024 by Support

# %% [markdown]
# When I refer to a "group," I mean a collection of institutions **larger than two**.

# %%
print("Frequent groups of institutions publishing highly cited works between 2019-2024 by support:")
freq_inst_groups = (
    
    # Filter to find the most frequent n-itemsets where n > 2
    frequent_itemsets[frequent_itemsets['length'] > 2]
    [['support', 'itemsets']]
)

display(freq_inst_groups.head())
# Out:
# Frequent groups of institutions publishing highly cited works between 2019-2024 by support:
#      support  \
# 320  0.00480
# 323  0.00436
# 319  0.00424
# 335  0.00370
# 318  0.00304
#
#                                                                             itemsets
# 320  frozenset({Harvard University, Massachusetts General Hospital, Mass General ...
# 323  frozenset({Australian Government, Department of Industry, Science and Resour...
# 319  frozenset({Harvard University, Brigham and Women's Hospital, Mass General Br...
# 335  frozenset({Chinese Academy of Agricultural Sciences, Ministry of Agriculture...
# 318  frozenset({Office of Science, Lawrence Berkeley National Laboratory, United ...

# %%
# Sort by support in descending order
freq_inst_groups = freq_inst_groups.sort_values(by='support', ascending=False)

# Plot the top ten groups of institutions by support
# Dataframe is sorted, first 10 rows will have the highest support
top_ten_groups = freq_inst_groups.head(10).plot.barh(
    x='itemsets',
    y='support',
    color='blue'
)

# Title and label the graph as approprite
top_ten_groups.set_title(label='Top 10 Frequent Institution Groups Publishing Highly Cited Works in 2019-2024', fontsize=24, color='black')
top_ten_groups.set_xlabel('Support', fontsize=18, color='black')
top_ten_groups.set_ylabel('Institution Name', fontsize=18, color='black')
top_ten_groups.legend(['Support'])

# Invert the y-axis to sort the bars in descending order
top_ten_groups.invert_yaxis()

# Annotate the bars
top_ten_groups.bar_label(top_ten_groups.containers[0], fmt='%f', label_type='center', color='white')
# Out:
# [Text(0, 0, '0.004800'),
#  Text(0, 0, '0.004360'),
#  Text(0, 0, '0.004240'),
#  Text(0, 0, '0.003700'),
#  Text(0, 0, '0.003040'),
#  Text(0, 0, '0.002940'),
#  Text(0, 0, '0.002820'),
#  Text(0, 0, '0.002820'),
#  Text(0, 0, '0.002820'),
#  Text(0, 0, '0.002820')]

# %% [markdown]
# These are the top ten institutions publishing highly cited works in groups **larger than two** between the years 2019-2024. Similar to the results for frequent pairs of institutions, there seems to be a preference to stay local as there does not seem to be a lot of international collaboration. A lot of these institutions are staying within their own ecosystems. Here, there seems to be more groups of federal institutions publishing together compared to the most frequent pairs.

# %% [markdown]
# ## Generating Association Rules

# %%
# Generate rules using Kulczynski as primary means of evaluation, a symmetric measure.
rules_df = association_rules(
    frequent_itemsets,
    metric='kulczynski',
    
    # Only interested in rules with moderate symmetry between conditional probabilities
    min_threshold=0.3,
    num_itemsets=len(frequent_itemsets),
)

print(f"Generated {len(rules_df):,} association rules")
rules_df.sort_values(by='kulczynski', ascending=False).head()
# Out:
# Generated 324 association rules
#                                                                          antecedents  \
# 128  frozenset({Ministère de l'Europe et des Affaires étrangères, Institut de Rec...
# 129  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 138  frozenset({Gouvernement de la République française, Institut de Recherche po...
# 139                    frozenset({Ministère de l'Europe et des Affaires étrangères})
# 141            frozenset({Institut de Recherche pour le Développement [4210166444]})
#
#                                                                          consequents  \
# 128  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 129  frozenset({Ministère de l'Europe et des Affaires étrangères, Institut de Rec...
# 138                    frozenset({Ministère de l'Europe et des Affaires étrangères})
# 139  frozenset({Gouvernement de la République française, Institut de Recherche po...
# 141  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
#
#      antecedent support  consequent support  support  confidence        lift  \
# 128             0.00282             0.00282  0.00282         1.0  354.609929
# 129             0.00282             0.00282  0.00282         1.0  354.609929
# 138             0.00282             0.00282  0.00282         1.0  354.609929
# 139             0.00282             0.00282  0.00282         1.0  354.609929
# 141             0.00282             0.00282  0.00282         1.0  354.609929
#
#      representativity  leverage  conviction  zhangs_metric  jaccard  \
# 128               1.0  0.002812         inf            1.0      1.0
# 129               1.0  0.002812         inf            1.0      1.0
# 138               1.0  0.002812         inf            1.0      1.0
# 139               1.0  0.002812         inf            1.0      1.0
# 141               1.0  0.002812         inf            1.0      1.0
#
#      certainty  kulczynski
# 128        1.0         1.0
# 129        1.0         1.0
# 138        1.0         1.0
# 139        1.0         1.0
# 141        1.0         1.0

# %% [markdown]
# I chose Kulczynski as my primary means of assessing rules because direction does not matter here but symmetry does. For example, if Harvard and Yale wrote a paper together it does not matter which one comes first as they are both associated with the work. For my secondary means of evaluation, I am looking at Jaccard similarity and lift. Jaccard similarity, like Kulczynski, is also a symmetric measure. It measures the similarity between two sets, but penalizes rare items that might have important information, which is why I chose Kulczynski as my primary means of evaluation. I use lift as a sanity check to see how much more likely this pair is to occur together than by random chance. The relationship needs to be symmetric to ensure that the institutions in question are actually publishing together somewhat frequently.

# %% [markdown]
# # Helper Functions for Rule Mining

# %%
def rules_involving(rules_df, label, side='either'):
    """
    Filter rules that involve a specific author display label.

    Parameters
    ----------
    rules_df : association rules DataFrame
    label    : str — the author display label (from author_display_map)
    side     : 'antecedent' | 'consequent' | 'either'
    """
    in_ant = rules_df['antecedents'].apply(lambda x: label in x)
    in_con = rules_df['consequents'].apply(lambda x: label in x)

    if side == 'antecedent':
        mask = in_ant
    elif side == 'consequent':
        mask = in_con
    else:
        mask = in_ant | in_con

    return rules_df[mask].sort_values('lift', ascending=False)


def rules_with_antecedent_size(rules_df, size):
    """Filter rules where the antecedent has exactly `size` items."""
    return rules_df[rules_df['antecedents'].apply(len) == size]

# Recycled from rules_with_antecedent_size to help with some of my searches
def rules_with_min_antecedent_size(rules_df, size):
    """Filter rules where the antecedent has at least `size` items."""
    return rules_df[rules_df['antecedents'].apply(len) >= size]


def rules_above_thresholds(rules_df, min_confidence=0.5, min_lift=2.0):
    """Filter rules meeting both confidence and lift thresholds."""
    return rules_df[
        (rules_df['confidence'] >= min_confidence) &
        (rules_df['lift']       >= min_lift)
    ]


def fmt_set(s):
    """Render a frozenset of author labels as a readable string."""
    return ', '.join(sorted(str(x) for x in s))

print("Helper functions defined ✅")
# Out:
# Helper functions defined ✅

# %% [markdown]
# # Filtering Rules for Institution Combinations

# %% [markdown]
# ## 1-1 Relationships

# %% [markdown]
# **"If institution A wrote this work, institution B also likely helped co-author this work"**

# %%
# Rules with a single-instutution antecedent and single-institution consequent
inst_1_to_1_rules = (

    # Filter for antecedent size of 1
    rules_with_antecedent_size(rules_df, 1)

    # Filter for consequent size of 1
    .pipe(lambda df: df[df['consequents'].apply(len) == 1])

    # Sort by Kulczynski to ensure symmetry
    .sort_values(by='kulczynski', ascending=False)
)

# Display the results, highlight the highest Kulczynski value
print(f"1-institution antecedent → 1-institution consequent: {len(inst_1_to_1_rules)} rules")
inst_1_to_1_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift', 'jaccard', 'kulczynski']].head(10).style.highlight_max('kulczynski')
# Out:
# 1-institution antecedent → 1-institution consequent: 116 rules
# <style type="text/css">
# #T_f3bf4_row0_col6, #T_f3bf4_row1_col6, #T_f3bf4_row2_col6, #T_f3bf4_row3_col6, #T_f3bf4_row4_col6, #T_f3bf4_row5_col6, #T_f3bf4_row6_col6, #T_f3bf4_row7_col6, #T_f3bf4_row8_col6, #T_f3bf4_row9_col6 {
#   background-color: yellow;
# }
# </style>
# <table id="T_f3bf4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3bf4_level0_col0" class="col_heading level0 col0" >antecedents</th>
#       <th id="T_f3bf4_level0_col1" class="col_heading level0 col1" >consequents</th>
#       <th id="T_f3bf4_level0_col2" class="col_heading level0 col2" >support</th>
#       <th id="T_f3bf4_level0_col3" class="col_heading level0 col3" >confidence</th>
#       <th id="T_f3bf4_level0_col4" class="col_heading level0 col4" >lift</th>
#       <th id="T_f3bf4_level0_col5" class="col_heading level0 col5" >jaccard</th>
#       <th id="T_f3bf4_level0_col6" class="col_heading level0 col6" >kulczynski</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3bf4_level0_row0" class="row_heading level0 row0" >161</th>
#       <td id="T_f3bf4_row0_col0" class="data row0 col0" >frozenset({'Institut de Recherche pour le Développement [4210166444]'})</td>
#       <td id="T_f3bf4_row0_col1" class="data row0 col1" >frozenset({'Ministère de l’Enseignement Supérieur et de la Recherche'})</td>
#       <td id="T_f3bf4_row0_col2" class="data row0 col2" >0.002820</td>
#       <td id="T_f3bf4_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_f3bf4_row0_col4" class="data row0 col4" >354.609929</td>
#       <td id="T_f3bf4_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_f3bf4_row0_col6" class="data row0 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f3bf4_level0_row1" class="row_heading level0 row1" >160</th>
#       <td id="T_f3bf4_row1_col0" class="data row1 col0" >frozenset({'Ministère de l’Enseignement Supérieur et de la Recherche'})</td>
#       <td id="T_f3bf4_row1_col1" class="data row1 col1" >frozenset({'Institut de Recherche pour le Développement [4210166444]'})</td>
#       <td id="T_f3bf4_row1_col2" class="data row1 col2" >0.002820</td>
#       <td id="T_f3bf4_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_f3bf4_row1_col4" class="data row1 col4" >354.609929</td>
#       <td id="T_f3bf4_row1_col5" class="data row1 col5" >1.000000</td>
#       <td id="T_f3bf4_row1_col6" class="data row1 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f3bf4_level0_row2" class="row_heading level0 row2" >107</th>
#       <td id="T_f3bf4_row2_col0" class="data row2 col0" >frozenset({'Indiana University'})</td>
#       <td id="T_f3bf4_row2_col1" class="data row2 col1" >frozenset({'Indiana University Columbus'})</td>
#       <td id="T_f3bf4_row2_col2" class="data row2 col2" >0.002980</td>
#       <td id="T_f3bf4_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_f3bf4_row2_col4" class="data row2 col4" >335.570470</td>
#       <td id="T_f3bf4_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_f3bf4_row2_col6" class="data row2 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f3bf4_level0_row3" class="row_heading level0 row3" >106</th>
#       <td id="T_f3bf4_row3_col0" class="data row3 col0" >frozenset({'Indiana University Columbus'})</td>
#       <td id="T_f3bf4_row3_col1" class="data row3 col1" >frozenset({'Indiana University'})</td>
#       <td id="T_f3bf4_row3_col2" class="data row3 col2" >0.002980</td>
#       <td id="T_f3bf4_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_f3bf4_row3_col4" class="data row3 col4" >335.570470</td>
#       <td id="T_f3bf4_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_f3bf4_row3_col6" class="data row3 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f3bf4_level0_row4" class="row_heading level0 row4" >149</th>
#       <td id="T_f3bf4_row4_col0" class="data row4 col0" >frozenset({'Ministère de l’Enseignement Supérieur et de la Recherche'})</td>
#       <td id="T_f3bf4_row4_col1" class="data row4 col1" >frozenset({"Ministère de l'Europe et des Affaires étrangères"})</td>
#       <td id="T_f3bf4_row4_col2" class="data row4 col2" >0.002820</td>
#       <td id="T_f3bf4_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_f3bf4_row4_col4" class="data row4 col4" >354.609929</td>
#       <td id="T_f3bf4_row4_col5" class="data row4 col5" >1.000000</td>
#       <td id="T_f3bf4_row4_col6" class="data row4 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f3bf4_level0_row5" class="row_heading level0 row5" >148</th>
#       <td id="T_f3bf4_row5_col0" class="data row5 col0" >frozenset({"Ministère de l'Europe et des Affaires étrangères"})</td>
#       <td id="T_f3bf4_row5_col1" class="data row5 col1" >frozenset({'Ministère de l’Enseignement Supérieur et de la Recherche'})</td>
#       <td id="T_f3bf4_row5_col2" class="data row5 col2" >0.002820</td>
#       <td id="T_f3bf4_row5_col3" class="data row5 col3" >1.000000</td>
#       <td id="T_f3bf4_row5_col4" class="data row5 col4" >354.609929</td>
#       <td id="T_f3bf4_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_f3bf4_row5_col6" class="data row5 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f3bf4_level0_row6" class="row_heading level0 row6" >152</th>
#       <td id="T_f3bf4_row6_col0" class="data row6 col0" >frozenset({"Ministère de l'Europe et des Affaires étrangères"})</td>
#       <td id="T_f3bf4_row6_col1" class="data row6 col1" >frozenset({'Institut de Recherche pour le Développement [4210166444]'})</td>
#       <td id="T_f3bf4_row6_col2" class="data row6 col2" >0.002820</td>
#       <td id="T_f3bf4_row6_col3" class="data row6 col3" >1.000000</td>
#       <td id="T_f3bf4_row6_col4" class="data row6 col4" >354.609929</td>
#       <td id="T_f3bf4_row6_col5" class="data row6 col5" >1.000000</td>
#       <td id="T_f3bf4_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f3bf4_level0_row7" class="row_heading level0 row7" >153</th>
#       <td id="T_f3bf4_row7_col0" class="data row7 col0" >frozenset({'Institut de Recherche pour le Développement [4210166444]'})</td>
#       <td id="T_f3bf4_row7_col1" class="data row7 col1" >frozenset({"Ministère de l'Europe et des Affaires étrangères"})</td>
#       <td id="T_f3bf4_row7_col2" class="data row7 col2" >0.002820</td>
#       <td id="T_f3bf4_row7_col3" class="data row7 col3" >1.000000</td>
#       <td id="T_f3bf4_row7_col4" class="data row7 col4" >354.609929</td>
#       <td id="T_f3bf4_row7_col5" class="data row7 col5" >1.000000</td>
#       <td id="T_f3bf4_row7_col6" class="data row7 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f3bf4_level0_row8" class="row_heading level0 row8" >182</th>
#       <td id="T_f3bf4_row8_col0" class="data row8 col0" >frozenset({'Harris Health System'})</td>
#       <td id="T_f3bf4_row8_col1" class="data row8 col1" >frozenset({'Baylor College of Medicine'})</td>
#       <td id="T_f3bf4_row8_col2" class="data row8 col2" >0.002640</td>
#       <td id="T_f3bf4_row8_col3" class="data row8 col3" >1.000000</td>
#       <td id="T_f3bf4_row8_col4" class="data row8 col4" >378.787879</td>
#       <td id="T_f3bf4_row8_col5" class="data row8 col5" >1.000000</td>
#       <td id="T_f3bf4_row8_col6" class="data row8 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f3bf4_level0_row9" class="row_heading level0 row9" >183</th>
#       <td id="T_f3bf4_row9_col0" class="data row9 col0" >frozenset({'Baylor College of Medicine'})</td>
#       <td id="T_f3bf4_row9_col1" class="data row9 col1" >frozenset({'Harris Health System'})</td>
#       <td id="T_f3bf4_row9_col2" class="data row9 col2" >0.002640</td>
#       <td id="T_f3bf4_row9_col3" class="data row9 col3" >1.000000</td>
#       <td id="T_f3bf4_row9_col4" class="data row9 col4" >378.787879</td>
#       <td id="T_f3bf4_row9_col5" class="data row9 col5" >1.000000</td>
#       <td id="T_f3bf4_row9_col6" class="data row9 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Similar to the pairs and groups of frequent institutions publishing together, a lot of these institutions publishing these highly cited works prefer to stay local. There are three main patterns here: federal institutions collaborating, universities collaborating with their satellite campuses, and institutions collaborating with their partners and subsidiaries.

# %% [markdown]
# **Example: Federal Collaboration**

# %%
rules_df.iloc[149]
# Out:
# antecedents           frozenset({Ministère de l’Enseignement Supérieur et de la Recherche})
# consequents                   frozenset({Ministère de l'Europe et des Affaires étrangères})
# antecedent support                                                                  0.00282
# consequent support                                                                  0.00282
# support                                                                             0.00282
# confidence                                                                              1.0
# lift                                                                             354.609929
# representativity                                                                        1.0
# leverage                                                                           0.002812
# conviction                                                                              inf
# zhangs_metric                                                                           1.0
# jaccard                                                                                 1.0
# certainty                                                                               1.0
# kulczynski                                                                              1.0
# Name: 149, dtype: object

# %% [markdown]
# **Example: Main Universities with their Satellite**

# %%
rules_df.iloc[107]
# Out:
# antecedents                    frozenset({Indiana University})
# consequents           frozenset({Indiana University Columbus})
# antecedent support                                     0.00298
# consequent support                                     0.00298
# support                                                0.00298
# confidence                                                 1.0
# lift                                                 335.57047
# representativity                                           1.0
# leverage                                              0.002971
# conviction                                                 inf
# zhangs_metric                                              1.0
# jaccard                                                    1.0
# certainty                                                  1.0
# kulczynski                                                 1.0
# Name: 107, dtype: object

# %% [markdown]
# **Example: Institution Partner Collaboration**

# %%
rules_df.iloc[183]
# Out:
# antecedents           frozenset({Baylor College of Medicine})
# consequents                 frozenset({Harris Health System})
# antecedent support                                    0.00264
# consequent support                                    0.00264
# support                                               0.00264
# confidence                                                1.0
# lift                                               378.787879
# representativity                                          1.0
# leverage                                             0.002633
# conviction                                                inf
# zhangs_metric                                             1.0
# jaccard                                                   1.0
# certainty                                                 1.0
# kulczynski                                                1.0
# Name: 183, dtype: object

# %% [markdown]
# ## 1-N Relationships

# %% [markdown]
# **"If institution A wrote this work, institutions B and C also likely helped co-author this work"**

# %%
# Rules with a single-instutution antecedent and n-institution consequent
inst_1_to_n_rules = (

    # Filter for antecedent size of 1
    rules_with_antecedent_size(rules_df, 1)

    # Filter for consequent size larger than 1
    .pipe(lambda df: df[df['consequents'].apply(len) > 1])

    # Sort by Kulczynski to ensure symmetry
    .sort_values(by='kulczynski', ascending=False)
)

print(f"1-institution antecedent → n-institution consequent: {len(inst_1_to_n_rules)} rules")
inst_1_to_n_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift', 'jaccard', 'kulczynski']].head(10)
# Out:
# 1-institution antecedent → n-institution consequent: 79 rules
#                                                                antecedents  \
# 145          frozenset({Ministère de l'Europe et des Affaires étrangères})
# 157          frozenset({Ministère de l'Europe et des Affaires étrangères})
# 147  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche})
# 169  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche})
# 171  frozenset({Institut de Recherche pour le Développement [4210166444]})
# 159  frozenset({Institut de Recherche pour le Développement [4210166444]})
# 158  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche})
# 141  frozenset({Institut de Recherche pour le Développement [4210166444]})
# 135  frozenset({Institut de Recherche pour le Développement [4210166444]})
# 139          frozenset({Ministère de l'Europe et des Affaires étrangères})
#
#                                                                          consequents  \
# 145  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 157  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Institu...
# 147  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 169  frozenset({Gouvernement de la République française, Institut de Recherche po...
# 171  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 159  frozenset({Ministère de l'Europe et des Affaires étrangères, Ministère de l’...
# 158  frozenset({Ministère de l'Europe et des Affaires étrangères, Institut de Rec...
# 141  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 135  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 139  frozenset({Gouvernement de la République française, Institut de Recherche po...
#
#      support  confidence        lift  jaccard  kulczynski
# 145  0.00282         1.0  354.609929      1.0         1.0
# 157  0.00282         1.0  354.609929      1.0         1.0
# 147  0.00282         1.0  354.609929      1.0         1.0
# 169  0.00282         1.0  354.609929      1.0         1.0
# 171  0.00282         1.0  354.609929      1.0         1.0
# 159  0.00282         1.0  354.609929      1.0         1.0
# 158  0.00282         1.0  354.609929      1.0         1.0
# 141  0.00282         1.0  354.609929      1.0         1.0
# 135  0.00282         1.0  354.609929      1.0         1.0
# 139  0.00282         1.0  354.609929      1.0         1.0

# %% [markdown]
# When it comes to groups of institutions larger than two, a majority of these groupings are various national and federal institutions collaborating with each other. These French institutions seem to rely on each other more compared to other groups of frequent 3-itemsets

# %%
frequent_itemsets[frequent_itemsets['length'] == 3]
# Out:
#      support  \
# 320  0.00480
# 323  0.00436
# 319  0.00424
# 335  0.00370
# 318  0.00304
# 321  0.00294
# 332  0.00282
# 331  0.00282
# 334  0.00282
# 333  0.00282
# 322  0.00268
# 327  0.00252
# 328  0.00252
# 329  0.00252
# 326  0.00252
# 324  0.00252
# 325  0.00252
# 330  0.00248
#
#                                                                             itemsets  \
# 320  frozenset({Harvard University, Massachusetts General Hospital, Mass General ...
# 323  frozenset({Australian Government, Department of Industry, Science and Resour...
# 319  frozenset({Harvard University, Brigham and Women's Hospital, Mass General Br...
# 335  frozenset({Chinese Academy of Agricultural Sciences, Ministry of Agriculture...
# 318  frozenset({Office of Science, Lawrence Berkeley National Laboratory, United ...
# 321  frozenset({Government of India, Council of Scientific and Industrial Researc...
# 332  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 331  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 334  frozenset({Ministère de l'Europe et des Affaires étrangères, Ministère de l’...
# 333  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 322  frozenset({Inserm, Centre National de la Recherche Scientifique, Institut de...
# 327  frozenset({Ministère de l'Europe et des Affaires étrangères, Centre National...
# 328  frozenset({Ministère de l'Europe et des Affaires étrangères, Centre National...
# 329  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Centre ...
# 326  frozenset({Gouvernement de la République française, Centre National de la Re...
# 324  frozenset({Gouvernement de la République française, Ministère de l'Europe et...
# 325  frozenset({Gouvernement de la République française, Ministère de l’Enseignem...
# 330  frozenset({United States Department of Health and Human Services, National C...
#
#      length
# 320       3
# 323       3
# 319       3
# 335       3
# 318       3
# 321       3
# 332       3
# 331       3
# 334       3
# 333       3
# 322       3
# 327       3
# 328       3
# 329       3
# 326       3
# 324       3
# 325       3
# 330       3

# %% [markdown]
# Even looking within the frequent 3-itemsets, it seems to be mostly groups of these French institutions.

# %% [markdown]
# ## N-1 Relationships

# %% [markdown]
# **"If institutions A and B wrote this work together, institution C also likely helped co-author this work"**

# %%
# Rules with an n-instutution antecedent and single-institution consequent
inst_n_to_1_rules = (

    # See helper functions
    # Filter for antecedent size larger than 1
    rules_with_min_antecedent_size(rules_df, 2)

    # Filter for consequent size of 1
    .pipe(lambda df: df[df['consequents'].apply(len) == 1])

    # Sort by Kulczynski to ensure symmetry
    .sort_values(by='kulczynski', ascending=False)
)

print(f"n-institution antecedent → 1-institution consequent: {len(inst_n_to_1_rules)} rules")
inst_n_to_1_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift', 'jaccard', 'kulczynski']].head(10)
# Out:
# n-institution antecedent → 1-institution consequent: 79 rules
#                                                                          antecedents  \
# 142  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 154  frozenset({Ministère de l'Europe et des Affaires étrangères, Ministère de l’...
# 144  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 166  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 168  frozenset({Gouvernement de la République française, Institut de Recherche po...
# 156  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Institu...
# 155  frozenset({Ministère de l'Europe et des Affaires étrangères, Institut de Rec...
# 138  frozenset({Gouvernement de la République française, Institut de Recherche po...
# 125  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 136  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
#
#                                                                consequents  \
# 142  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche})
# 154  frozenset({Institut de Recherche pour le Développement [4210166444]})
# 144          frozenset({Ministère de l'Europe et des Affaires étrangères})
# 166  frozenset({Institut de Recherche pour le Développement [4210166444]})
# 168  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche})
# 156          frozenset({Ministère de l'Europe et des Affaires étrangères})
# 155  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche})
# 138          frozenset({Ministère de l'Europe et des Affaires étrangères})
# 125          frozenset({Ministère de l'Europe et des Affaires étrangères})
# 136  frozenset({Institut de Recherche pour le Développement [4210166444]})
#
#      support  confidence        lift  jaccard  kulczynski
# 142  0.00282         1.0  354.609929      1.0         1.0
# 154  0.00282         1.0  354.609929      1.0         1.0
# 144  0.00282         1.0  354.609929      1.0         1.0
# 166  0.00282         1.0  354.609929      1.0         1.0
# 168  0.00282         1.0  354.609929      1.0         1.0
# 156  0.00282         1.0  354.609929      1.0         1.0
# 155  0.00282         1.0  354.609929      1.0         1.0
# 138  0.00282         1.0  354.609929      1.0         1.0
# 125  0.00282         1.0  354.609929      1.0         1.0
# 136  0.00282         1.0  354.609929      1.0         1.0

# %% [markdown]
# Same results as the 1-N pairings, added to prove symmetry.

# %% [markdown]
# # M-N Relationships

# %% [markdown]
# **"If institutions A, ..., M wrote this work together, institutions (M + 1), ..., N also likely helped co-author this work"**

# %%
# Rules with an m-instutution antecedent and n-institution consequent
inst_m_to_n_rules = (

    # See helper functions
    # Filter for antecedent size larger than 1
    rules_with_min_antecedent_size(rules_df, 2)

    # Filter for consequent size larger than 1
    .pipe(lambda df: df[df['consequents'].apply(len) > 1])
    .sort_values(by='kulczynski', ascending=False)
)

print(f"m-institution antecedent → n-institution consequent: {len(inst_m_to_n_rules)} rules")
inst_m_to_n_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift', 'jaccard', 'kulczynski']]
# Out:
# m-institution antecedent → n-institution consequent: 50 rules
#                                                                          antecedents  \
# 126  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 127  frozenset({Ministère de l'Europe et des Affaires étrangères, Ministère de l’...
# 128  frozenset({Ministère de l'Europe et des Affaires étrangères, Institut de Rec...
# 129  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 130  frozenset({Gouvernement de la République française, Institut de Recherche po...
# 131  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Institu...
# 194  frozenset({Ministère de l'Europe et des Affaires étrangères, Centre National...
# 195  frozenset({Ministère de l'Europe et des Affaires étrangères, Ministère de l’...
# 196  frozenset({Ministère de l'Europe et des Affaires étrangères, Institut de Rec...
# 197  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Centre ...
# 198  frozenset({Centre National de la Recherche Scientifique, Institut de Recherc...
# 199  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Institu...
# 221  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 222  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Centre ...
# 224  frozenset({Ministère de l'Europe et des Affaires étrangères, Centre National...
# 223  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 236  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 235  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 309  frozenset({Centre National de la Recherche Scientifique, Institut de Recherc...
# 308  frozenset({Gouvernement de la République française, Institut de Recherche po...
# 237  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 238  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 239  frozenset({Gouvernement de la République française, Centre National de la Re...
# 240  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 242  frozenset({Ministère de l'Europe et des Affaires étrangères, Centre National...
# 243  frozenset({Ministère de l'Europe et des Affaires étrangères, Centre National...
# 247  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 244  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Centre ...
# 245  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 246  frozenset({Gouvernement de la République française, Institut de Recherche po...
# 250  frozenset({Ministère de l'Europe et des Affaires étrangères, Ministère de l’...
# 249  frozenset({Ministère de l'Europe et des Affaires étrangères, Institut de Rec...
# 252  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Institu...
# 251  frozenset({Ministère de l'Europe et des Affaires étrangères, Centre National...
# 304  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 305  frozenset({Ministère de l'Europe et des Affaires étrangères, Centre National...
# 253  frozenset({Centre National de la Recherche Scientifique, Institut de Recherc...
# 254  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Centre ...
# 264  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 265  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Centre ...
# 269  frozenset({Centre National de la Recherche Scientifique, Institut de Recherc...
# 268  frozenset({Gouvernement de la République française, Institut de Recherche po...
# 225  frozenset({Gouvernement de la République française, Centre National de la Re...
# 220  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Ministè...
# 248  frozenset({Gouvernement de la République française, Centre National de la Re...
# 241  frozenset({Ministère de l'Europe et des Affaires étrangères, Ministère de l’...
# 267  frozenset({Gouvernement de la République française, Centre National de la Re...
# 266  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Institu...
# 307  frozenset({Gouvernement de la République française, Centre National de la Re...
# 306  frozenset({Ministère de l'Europe et des Affaires étrangères, Institut de Rec...
#
#                                                                          consequents  \
# 126  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Institu...
# 127  frozenset({Gouvernement de la République française, Institut de Recherche po...
# 128  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 129  frozenset({Ministère de l'Europe et des Affaires étrangères, Institut de Rec...
# 130  frozenset({Ministère de l'Europe et des Affaires étrangères, Ministère de l’...
# 131  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 194  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Institu...
# 195  frozenset({Centre National de la Recherche Scientifique, Institut de Recherc...
# 196  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Centre ...
# 197  frozenset({Ministère de l'Europe et des Affaires étrangères, Institut de Rec...
# 198  frozenset({Ministère de l'Europe et des Affaires étrangères, Ministère de l’...
# 199  frozenset({Ministère de l'Europe et des Affaires étrangères, Centre National...
# 221  frozenset({Ministère de l'Europe et des Affaires étrangères, Centre National...
# 222  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 224  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 223  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Centre ...
# 236  frozenset({Centre National de la Recherche Scientifique, Institut de Recherc...
# 235  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Centre ...
# 309  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 308  frozenset({Ministère de l'Europe et des Affaires étrangères, Centre National...
# 237  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Institu...
# 238  frozenset({Ministère de l'Europe et des Affaires étrangères, Centre National...
# 239  frozenset({Ministère de l'Europe et des Affaires étrangères, Ministère de l’...
# 240  frozenset({Ministère de l'Europe et des Affaires étrangères, Institut de Rec...
# 242  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 243  frozenset({Gouvernement de la République française, Institut de Recherche po...
# 247  frozenset({Ministère de l'Europe et des Affaires étrangères, Centre National...
# 244  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 245  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Centre ...
# 246  frozenset({Ministère de l'Europe et des Affaires étrangères, Centre National...
# 250  frozenset({Gouvernement de la République française, Centre National de la Re...
# 249  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 252  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 251  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 304  frozenset({Centre National de la Recherche Scientifique, Institut de Recherc...
# 305  frozenset({Gouvernement de la République française, Institut de Recherche po...
# 253  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 254  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 264  frozenset({Centre National de la Recherche Scientifique, Institut de Recherc...
# 265  frozenset({Gouvernement de la République française, Institut de Recherche po...
# 269  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Gouvern...
# 268  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Centre ...
# 225  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Ministè...
# 220  frozenset({Gouvernement de la République française, Centre National de la Re...
# 248  frozenset({Ministère de l'Europe et des Affaires étrangères, Ministère de l’...
# 241  frozenset({Gouvernement de la République française, Centre National de la Re...
# 267  frozenset({Ministère de l’Enseignement Supérieur et de la Recherche, Institu...
# 266  frozenset({Gouvernement de la République française, Centre National de la Re...
# 307  frozenset({Ministère de l'Europe et des Affaires étrangères, Institut de Rec...
# 306  frozenset({Gouvernement de la République française, Centre National de la Re...
#
#      support  confidence        lift   jaccard  kulczynski
# 126  0.00282    1.000000  354.609929  1.000000    1.000000
# 127  0.00282    1.000000  354.609929  1.000000    1.000000
# 128  0.00282    1.000000  354.609929  1.000000    1.000000
# 129  0.00282    1.000000  354.609929  1.000000    1.000000
# 130  0.00282    1.000000  354.609929  1.000000    1.000000
# 131  0.00282    1.000000  354.609929  1.000000    1.000000
# 194  0.00252    1.000000  354.609929  0.893617    0.946809
# 195  0.00252    0.893617  354.609929  0.893617    0.946809
# 196  0.00252    0.893617  354.609929  0.893617    0.946809
# 197  0.00252    1.000000  354.609929  0.893617    0.946809
# 198  0.00252    1.000000  354.609929  0.893617    0.946809
# 199  0.00252    0.893617  354.609929  0.893617    0.946809
# 221  0.00252    0.893617  354.609929  0.893617    0.946809
# 222  0.00252    1.000000  354.609929  0.893617    0.946809
# 224  0.00252    1.000000  354.609929  0.893617    0.946809
# 223  0.00252    0.893617  354.609929  0.893617    0.946809
# 236  0.00252    0.893617  354.609929  0.893617    0.946809
# 235  0.00252    0.893617  354.609929  0.893617    0.946809
# 309  0.00252    1.000000  354.609929  0.893617    0.946809
# 308  0.00252    0.893617  354.609929  0.893617    0.946809
# 237  0.00252    1.000000  354.609929  0.893617    0.946809
# 238  0.00252    0.893617  354.609929  0.893617    0.946809
# 239  0.00252    1.000000  354.609929  0.893617    0.946809
# 240  0.00252    1.000000  354.609929  0.893617    0.946809
# 242  0.00252    1.000000  354.609929  0.893617    0.946809
# 243  0.00252    1.000000  354.609929  0.893617    0.946809
# 247  0.00252    0.893617  354.609929  0.893617    0.946809
# 244  0.00252    1.000000  354.609929  0.893617    0.946809
# 245  0.00252    0.893617  354.609929  0.893617    0.946809
# 246  0.00252    0.893617  354.609929  0.893617    0.946809
# 250  0.00252    0.893617  354.609929  0.893617    0.946809
# 249  0.00252    0.893617  354.609929  0.893617    0.946809
# 252  0.00252    0.893617  354.609929  0.893617    0.946809
# 251  0.00252    1.000000  354.609929  0.893617    0.946809
# 304  0.00252    0.893617  354.609929  0.893617    0.946809
# 305  0.00252    1.000000  354.609929  0.893617    0.946809
# 253  0.00252    1.000000  354.609929  0.893617    0.946809
# 254  0.00252    1.000000  354.609929  0.893617    0.946809
# 264  0.00252    0.893617  354.609929  0.893617    0.946809
# 265  0.00252    1.000000  354.609929  0.893617    0.946809
# 269  0.00252    1.000000  354.609929  0.893617    0.946809
# 268  0.00252    0.893617  354.609929  0.893617    0.946809
# 225  0.00252    0.961832  341.075199  0.863014    0.927725
# 220  0.00252    0.893617  341.075199  0.863014    0.927725
# 248  0.00252    0.961832  341.075199  0.863014    0.927725
# 241  0.00252    0.893617  341.075199  0.863014    0.927725
# 267  0.00252    0.961832  341.075199  0.863014    0.927725
# 266  0.00252    0.893617  341.075199  0.863014    0.927725
# 307  0.00252    0.961832  341.075199  0.863014    0.927725
# 306  0.00252    0.893617  341.075199  0.863014    0.927725

# %% [markdown]
# When it comes to groups of institutions larger than two, these French institutions seem to constitute the only frequent itemsets larger than size three. Given the strong symmetry, this can be interpreted in a few different ways. The first way this could be interpreted is that these groups of institutions rely on each other more than other groupings do and rarely act independently from one another. The second way this could be interpreted is that these Francophone countries (i.e. Belgium, France, Switzerland) have much stricter federal guidelines for academic research and that any academic research being published in these countries needs to pass through these institutions in order to be published, which is why these institutions appear together most frequently.

# %%
# Confirmed
frequent_itemsets[frequent_itemsets['length'] > 3]
# Out:
#      support  \
# 340  0.00282
# 339  0.00252
# 336  0.00252
# 341  0.00252
# 338  0.00252
# 337  0.00252
#
#                                                                             itemsets  \
# 340  frozenset({Ministère de l'Europe et des Affaires étrangères, Gouvernement de...
# 339  frozenset({Ministère de l'Europe et des Affaires étrangères, Centre National...
# 336  frozenset({Gouvernement de la République française, Ministère de l'Europe et...
# 341  frozenset({Gouvernement de la République française, Ministère de l'Europe et...
# 338  frozenset({Gouvernement de la République française, Ministère de l’Enseignem...
# 337  frozenset({Gouvernement de la République française, Ministère de l'Europe et...
#
#      length
# 340       4
# 339       4
# 336       4
# 341       5
# 338       4
# 337       4

# %% [markdown]
# # Rule Metric Relationships and Outlier Rules

# %%
# Construct a 3-panel scatterplot comparing lift, jaccard, and kulczynski measures
# of the generated rule metrics
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Construct a scatter plot for each metric, adjusted transparency, size, and color for readability
for ax, y_metric in zip(axes, ['lift', 'jaccard', 'kulczynski']):
    ax.scatter(rules_df['support'], rules_df[y_metric],
               alpha=1, s=12, color='blue')
    ax.set_xlabel('support', fontsize=18, color='black')
    ax.set_ylabel(y_metric, fontsize=18, color='black')
    ax.set_title(f'{y_metric} vs support', fontsize=21, color='black')

plt.suptitle("Rule Metric Relationships", fontsize=24, color='black')
plt.tight_layout()
plt.show()

# %% [markdown]
# Plots the relationships between my chosen rule evaluation metrics against support. Interestingly, the rules with lower supports seem to have the best scores for Jaccard, Kulczynski, and lift respectively. A lot of these "outlier rules" are the ones with the highest support values.

# %%
# Peek at the top 25 "outlier rules" sort by support
rules_df.sort_values(by='support', ascending=False).head(50).style.highlight_max('support')
# Out:
# <style type="text/css">
# #T_4520b_row0_col4, #T_4520b_row1_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_4520b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4520b_level0_col0" class="col_heading level0 col0" >antecedents</th>
#       <th id="T_4520b_level0_col1" class="col_heading level0 col1" >consequents</th>
#       <th id="T_4520b_level0_col2" class="col_heading level0 col2" >antecedent support</th>
#       <th id="T_4520b_level0_col3" class="col_heading level0 col3" >consequent support</th>
#       <th id="T_4520b_level0_col4" class="col_heading level0 col4" >support</th>
#       <th id="T_4520b_level0_col5" class="col_heading level0 col5" >confidence</th>
#       <th id="T_4520b_level0_col6" class="col_heading level0 col6" >lift</th>
#       <th id="T_4520b_level0_col7" class="col_heading level0 col7" >representativity</th>
#       <th id="T_4520b_level0_col8" class="col_heading level0 col8" >leverage</th>
#       <th id="T_4520b_level0_col9" class="col_heading level0 col9" >conviction</th>
#       <th id="T_4520b_level0_col10" class="col_heading level0 col10" >zhangs_metric</th>
#       <th id="T_4520b_level0_col11" class="col_heading level0 col11" >jaccard</th>
#       <th id="T_4520b_level0_col12" class="col_heading level0 col12" >certainty</th>
#       <th id="T_4520b_level0_col13" class="col_heading level0 col13" >kulczynski</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4520b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4520b_row0_col0" class="data row0 col0" >frozenset({'Chinese Academy of Sciences'})</td>
#       <td id="T_4520b_row0_col1" class="data row0 col1" >frozenset({'University of Chinese Academy of Sciences'})</td>
#       <td id="T_4520b_row0_col2" class="data row0 col2" >0.049320</td>
#       <td id="T_4520b_row0_col3" class="data row0 col3" >0.017280</td>
#       <td id="T_4520b_row0_col4" class="data row0 col4" >0.017280</td>
#       <td id="T_4520b_row0_col5" class="data row0 col5" >0.350365</td>
#       <td id="T_4520b_row0_col6" class="data row0 col6" >20.275750</td>
#       <td id="T_4520b_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_4520b_row0_col8" class="data row0 col8" >0.016428</td>
#       <td id="T_4520b_row0_col9" class="data row0 col9" >1.512726</td>
#       <td id="T_4520b_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_4520b_row0_col11" class="data row0 col11" >0.350365</td>
#       <td id="T_4520b_row0_col12" class="data row0 col12" >0.338942</td>
#       <td id="T_4520b_row0_col13" class="data row0 col13" >0.675182</td>
#     </tr>
#     <tr>
#       <th id="T_4520b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4520b_row1_col0" class="data row1 col0" >frozenset({'University of Chinese Academy of Sciences'})</td>
#       <td id="T_4520b_row1_col1" class="data row1 col1" >frozenset({'Chinese Academy of Sciences'})</td>
#       <td id="T_4520b_row1_col2" class="data row1 col2" >0.017280</td>
#       <td id="T_4520b_row1_col3" class="data row1 col3" >0.049320</td>
#       <td id="T_4520b_row1_col4" class="data row1 col4" >0.017280</td>
#       <td id="T_4520b_row1_col5" class="data row1 col5" >1.000000</td>
#       <td id="T_4520b_row1_col6" class="data row1 col6" >20.275750</td>
#       <td id="T_4520b_row1_col7" class="data row1 col7" >1.000000</td>
#       <td id="T_4520b_row1_col8" class="data row1 col8" >0.016428</td>
#       <td id="T_4520b_row1_col9" class="data row1 col9" >inf</td>
#       <td id="T_4520b_row1_col10" class="data row1 col10" >0.967397</td>
#       <td id="T_4520b_row1_col11" class="data row1 col11" >0.350365</td>
#       <td id="T_4520b_row1_col12" class="data row1 col12" >1.000000</td>
#       <td id="T_4520b_row1_col13" class="data row1 col13" >0.675182</td>
#     </tr>
#     <tr>
#       <th id="T_4520b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4520b_row2_col0" class="data row2 col0" >frozenset({'University College London'})</td>
#       <td id="T_4520b_row2_col1" class="data row2 col1" >frozenset({'University of London'})</td>
#       <td id="T_4520b_row2_col2" class="data row2 col2" >0.010080</td>
#       <td id="T_4520b_row2_col3" class="data row2 col3" >0.020440</td>
#       <td id="T_4520b_row2_col4" class="data row2 col4" >0.010080</td>
#       <td id="T_4520b_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_4520b_row2_col6" class="data row2 col6" >48.923679</td>
#       <td id="T_4520b_row2_col7" class="data row2 col7" >1.000000</td>
#       <td id="T_4520b_row2_col8" class="data row2 col8" >0.009874</td>
#       <td id="T_4520b_row2_col9" class="data row2 col9" >inf</td>
#       <td id="T_4520b_row2_col10" class="data row2 col10" >0.989535</td>
#       <td id="T_4520b_row2_col11" class="data row2 col11" >0.493151</td>
#       <td id="T_4520b_row2_col12" class="data row2 col12" >1.000000</td>
#       <td id="T_4520b_row2_col13" class="data row2 col13" >0.746575</td>
#     </tr>
#     <tr>
#       <th id="T_4520b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4520b_row3_col0" class="data row3 col0" >frozenset({'University of London'})</td>
#       <td id="T_4520b_row3_col1" class="data row3 col1" >frozenset({'University College London'})</td>
#       <td id="T_4520b_row3_col2" class="data row3 col2" >0.020440</td>
#       <td id="T_4520b_row3_col3" class="data row3 col3" >0.010080</td>
#       <td id="T_4520b_row3_col4" class="data row3 col4" >0.010080</td>
#       <td id="T_4520b_row3_col5" class="data row3 col5" >0.493151</td>
#       <td id="T_4520b_row3_col6" class="data row3 col6" >48.923679</td>
#       <td id="T_4520b_row3_col7" class="data row3 col7" >1.000000</td>
#       <td id="T_4520b_row3_col8" class="data row3 col8" >0.009874</td>
#       <td id="T_4520b_row3_col9" class="data row3 col9" >1.953085</td>
#       <td id="T_4520b_row3_col10" class="data row3 col10" >1.000000</td>
#       <td id="T_4520b_row3_col11" class="data row3 col11" >0.493151</td>
#       <td id="T_4520b_row3_col12" class="data row3 col12" >0.487990</td>
#       <td id="T_4520b_row3_col13" class="data row3 col13" >0.746575</td>
#     </tr>
#     <tr>
#       <th id="T_4520b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4520b_row4_col0" class="data row4 col0" >frozenset({'Office of Science'})</td>
#       <td id="T_4520b_row4_col1" class="data row4 col1" >frozenset({'United States Department of Energy'})</td>
#       <td id="T_4520b_row4_col2" class="data row4 col2" >0.009940</td>
#       <td id="T_4520b_row4_col3" class="data row4 col3" >0.012780</td>
#       <td id="T_4520b_row4_col4" class="data row4 col4" >0.009940</td>
#       <td id="T_4520b_row4_col5" class="data row4 col5" >1.000000</td>
#       <td id="T_4520b_row4_col6" class="data row4 col6" >78.247261</td>
#       <td id="T_4520b_row4_col7" class="data row4 col7" >1.000000</td>
#       <td id="T_4520b_row4_col8" class="data row4 col8" >0.009813</td>
#       <td id="T_4520b_row4_col9" class="data row4 col9" >inf</td>
#       <td id="T_4520b_row4_col10" class="data row4 col10" >0.997131</td>
#       <td id="T_4520b_row4_col11" class="data row4 col11" >0.777778</td>
#       <td id="T_4520b_row4_col12" class="data row4 col12" >1.000000</td>
#       <td id="T_4520b_row4_col13" class="data row4 col13" >0.888889</td>
#     </tr>
#     <tr>
#       <th id="T_4520b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4520b_row5_col0" class="data row5 col0" >frozenset({'United States Department of Energy'})</td>
#       <td id="T_4520b_row5_col1" class="data row5 col1" >frozenset({'Office of Science'})</td>
#       <td id="T_4520b_row5_col2" class="data row5 col2" >0.012780</td>
#       <td id="T_4520b_row5_col3" class="data row5 col3" >0.009940</td>
#       <td id="T_4520b_row5_col4" class="data row5 col4" >0.009940</td>
#       <td id="T_4520b_row5_col5" class="data row5 col5" >0.777778</td>
#       <td id="T_4520b_row5_col6" class="data row5 col6" >78.247261</td>
#       <td id="T_4520b_row5_col7" class="data row5 col7" >1.000000</td>
#       <td id="T_4520b_row5_col8" class="data row5

# %% [markdown]
# When sorted by support, there is a much greater diversity of institution pairings compared to when sorted by Kulczynski. These pairings here constitute the "outliers" on the rule metric relationship plots as the outlier points had higher support values. The lower symmetry and lift between these groupings of institutions suggest that they tend to act independently from each other more often than the French institutions examined earlier. Nevertheless, similar patterns can be traced here as these pairings consist mostly of institutions collaboraring with either federal institutions or their partners and subsidiaries. A lot of these institutions seem to prefer to stick within their own ecosystems. This dispels the possibility that the institutions associated with publishing the most frequently cited works "gatekeep" highly cited academic works by just collaborating with each other.
